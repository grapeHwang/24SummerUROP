# %% [markdown]
# data augmentation 활용
# 맨 뒤 30개의 레이어만 재학습

# %% [markdown]
# # 데이터 준비

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Flatten, GlobalMaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
import random
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

# %%
seed = 126
IMAGE_SIZE = (224, 224)

# %%
batch_size = 128

# %%
root_path = '/content/drive/MyDrive/2024urop/dataset'
labels = []
trainFolder = root_path+'/Training/'
testFolder = root_path+'/Testing/'

quantity_tr = {}
quantity_te = {}
for folder in os.listdir(trainFolder):
    quantity_tr[folder] = len(os.listdir(trainFolder+folder))
    labels.append(folder)

for folder in os.listdir(testFolder):
    quantity_te[folder] = len(os.listdir(testFolder+folder))


quantity_train = pd.DataFrame(list(quantity_tr.items()),
                              index=range(0,len(quantity_tr)), columns=['class','count'])

quantity_test = pd.DataFrame(list(quantity_te.items()),
                              index=range(0,len(quantity_te)), columns=['class','count'])

figure, ax = plt.subplots(1,2,figsize=(12,5))
sns.barplot(x='class',y='count',data=quantity_train,ax=ax[0])
sns.barplot(x='class',y='count',data=quantity_test,ax=ax[1])

print("Number of images in training: ", sum(quantity_tr.values()))
print("Number of images in testing: ", sum(quantity_te.values()))

plt.show()
# Out:
# Number of images in training:  5712
# Number of images in testing:  1311

# %%
labels
# Out:
# ['notumor', 'pituitary', 'glioma', 'meningioma']

# %%
# reading the dataset
X_train = []
y_train = []

X_test = []
y_test = []

for i in labels:
    folderPath = os.path.join(root_path,'Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j), 1)
        img = cv2.resize(img,(IMAGE_SIZE[0], IMAGE_SIZE[1]))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join(root_path,'Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j), 1)
        img = cv2.resize(img,(IMAGE_SIZE[0], IMAGE_SIZE[1]))
        X_test.append(img)
        y_test.append(i)
# Out:
# 100%|██████████| 1595/1595 [00:43<00:00, 36.50it/s]
# 100%|██████████| 1457/1457 [00:32<00:00, 44.90it/s]
# 100%|██████████| 1321/1321 [00:27<00:00, 47.42it/s]
# 100%|██████████| 1339/1339 [00:40<00:00, 33.39it/s]
# 100%|██████████| 405/405 [00:05<00:00, 68.02it/s]
# 100%|██████████| 300/300 [00:04<00:00, 67.44it/s]
# 100%|██████████| 300/300 [00:04<00:00, 66.41it/s]
# 100%|██████████| 306/306 [00:04<00:00, 76.41it/s]

# %%
# python list to numpy array
X_train = np.array(X_train)
y_train = np.array(y_train)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
# rescaling
X_train=X_train/255.0
X_test=X_test/255.0

# %%
print(np.min(X_train), np.max(X_train))
# Out:
# 0.0 1.0

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5712, 224, 224, 3) (5712,)
# (1311, 224, 224, 3) (1311,)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5712, 224, 224, 3) (5712, 4)
# (1311, 224, 224, 3) (1311, 4)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

train_datagen = ImageDataGenerator(
        rotation_range=20,         # 이미지를 무작위로 0도에서 20도까지 회전
        width_shift_range=0.2,     # 이미지를 좌우로 무작위 이동 (전체 가로 길이의 20%까지)
        height_shift_range=0.2,    # 이미지를 위아래로 무작위 이동 (전체 세로 길이의 20%까지)
        shear_range=0.15,          # 이미지를 무작위로 전단 변환
        zoom_range=0.2,            # 이미지를 무작위로 확대/축소 (0.8배에서 1.2배 사이)
        horizontal_flip=True,      # 이미지를 수평으로 무작위 뒤집기
        fill_mode='nearest',
        validation_split = 0.2
)
test_datagen = ImageDataGenerator()


train_ds = train_datagen.flow(
  X_train, y_train,
  subset="training",
  shuffle=True,
  batch_size=batch_size)

# %%
val_ds = train_datagen.flow(
  X_train, y_train,
  subset="validation",
  shuffle=True,
  batch_size=batch_size)

# %%
test_ds = test_datagen.flow(
  X_test, y_test,
  shuffle=False,
  batch_size=batch_size)

# %%
j = 0
class_mapping = {}
for i in labels:
    class_mapping[j] = i
    j+=1

class_mapping
# Out:
# {0: 'notumor', 1: 'pituitary', 2: 'glioma', 3: 'meningioma'}

# %%
def show_few_images(number_of_examples=2, predict_using_model=None):
    figure1, ax1 = plt.subplots(number_of_examples,len(os.listdir(testFolder)), figsize=(20,4*number_of_examples))
    ax1 = ax1.reshape(-1)
    axoff_fun = np.vectorize(lambda ax:ax.axis('off'))
    axoff_fun(ax1)
    axs = 0
    for i, folder in enumerate(os.listdir(testFolder)):
        image_ids = os.listdir(os.path.join(testFolder,folder))
        for j in [random.randrange(0, len(image_ids)) for i in range(0,number_of_examples)]:

            display = cv2.imread(os.path.join(testFolder,folder,image_ids[j]),1)
            display = cv2.resize(display, (IMAGE_SIZE[0], IMAGE_SIZE[1]))/255.0
            plt.axis('off')
            ax1[axs].imshow(display)
            title = 'True: '+folder
            if(predict_using_model):
                result = predict_using_model.predict(np.array([display]))
                #print(result)
                acc = str(round(np.max(result)*100, 3))
                predicted_classname = class_mapping[np.argmax(result)]
                title = title+'\nPrediction : '+predicted_classname+" - "+acc+"%"
            ax1[axs].set_title(title)
            axs=axs+1

# %%
show_few_images(3)

# %% [markdown]
# # 모델 구조

# %%
class_count = 4
channels = 3
base_model = MobileNetV2(include_top = False, weights = 'imagenet',
                         input_shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], channels), pooling = 'max')
base_model.trainable = False
for i in range(153):
  if (i+1) % 5 == 0 :
    base_model.layers[-i].trainable = True

np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)


model = Sequential([
    base_model,
    BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001),
    Dense(256, kernel_regularizer = regularizers.l2(0.016),
          activity_regularizer = regularizers.l1(0.006),
          activation = 'relu'),
    Dropout(rate = 0.45, seed = 123),
    Dense(class_count, activation = 'softmax')
])

model.build(input_shape = (None, *(IMAGE_SIZE[0], IMAGE_SIZE[1], channels)))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 1280)              2257984
#  tional)
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 2592068 (9.89 MB)
# Trainable params: 331524 (1.26 MB)
# Non-trainable params: 2260544 (8.62 MB)
# _________________________________________________________________

# %% [markdown]
# # 모델 실행

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adamax(learning_rate = 0.001), metrics = ['accuracy'])

# %%
modelpath = '/content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras'
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 10)
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only = True)
history = model.fit(train_ds, validation_data = val_ds, epochs = 100, callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 7.4642 - accuracy: 0.7611
# Epoch 1: val_loss improved from inf to 8.70524, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 81s 2s/step - loss: 7.4642 - accuracy: 0.7611 - val_loss: 8.7052 - val_accuracy: 0.4518
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 5.7958 - accuracy: 0.8350
# Epoch 2: val_loss improved from 8.70524 to 6.77002, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 5.7958 - accuracy: 0.8350 - val_loss: 6.7700 - val_accuracy: 0.4904
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 4.6491 - accuracy: 0.8499
# Epoch 3: val_loss improved from 6.77002 to 5.25788, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 4.6491 - accuracy: 0.8499 - val_loss: 5.2579 - val_accuracy: 0.5692
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 3.7695 - accuracy: 0.8726
# Epoch 4: val_loss improved from 5.25788 to 4.35422, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 3.7695 - accuracy: 0.8726 - val_loss: 4.3542 - val_accuracy: 0.5674
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 3.0892 - accuracy: 0.8858
# Epoch 5: val_loss improved from 4.35422 to 3.68107, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 3.0892 - accuracy: 0.8858 - val_loss: 3.6811 - val_accuracy: 0.5876
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 2.5612 - accuracy: 0.8906
# Epoch 6: val_loss improved from 3.68107 to 3.13010, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 72s 2s/step - loss: 2.5612 - accuracy: 0.8906 - val_loss: 3.1301 - val_accuracy: 0.5963
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 2.1586 - accuracy: 0.8864
# Epoch 7: val_loss improved from 3.13010 to 2.56359, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 2.1586 - accuracy: 0.8864 - val_loss: 2.5636 - val_accuracy: 0.6349
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 1.8230 - accuracy: 0.8910
# Epoch 8: val_loss improved from 2.56359 to 2.13065, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 1.8230 - accuracy: 0.8910 - val_loss: 2.1307 - val_accuracy: 0.6664
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 1.5550 - accuracy: 0.8972
# Epoch 9: val_loss improved from 2.13065 to 1.91565, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 1.5550 - accuracy: 0.8972 - val_loss: 1.9157 - val_accuracy: 0.6515
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 1.3360 - accuracy: 0.9066
# Epoch 10: val_loss improved from 1.91565 to 1.60938, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 1.3360 - accuracy: 0.9066 - val_loss: 1.6094 - val_accuracy: 0.7198
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 1.1665 - accuracy: 0.9053
# Epoch 11: val_loss improved from 1.60938 to 1.54100, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 1.1665 - accuracy: 0.9053 - val_loss: 1.5410 - val_accuracy: 0.6979
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0321 - accuracy: 0.9079
# Epoch 12: val_loss improved from 1.54100 to 1.30714, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 1.0321 - accuracy: 0.9079 - val_loss: 1.3071 - val_accuracy: 0.7294
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 0.9191 - accuracy: 0.9120
# Epoch 13: val_loss improved from 1.30714 to 1.25831, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.9191 - accuracy: 0.9120 - val_loss: 1.2583 - val_accuracy: 0.6944
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 0.8248 - accuracy: 0.9199
# Epoch 14: val_loss improved from 1.25831 to 1.09289, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.8248 - accuracy: 0.9199 - val_loss: 1.0929 - val_accuracy: 0.7609
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 0.7577 - accuracy: 0.9131
# Epoch 15: val_loss improved from 1.09289 to 1.05797, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.7577 - accuracy: 0.9131 - val_loss: 1.0580 - val_accuracy: 0.7364
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 0.7024 - accuracy: 0.9151
# Epoch 16: val_loss improved from 1.05797 to 0.95502, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.7024 - accuracy: 0.9151 - val_loss: 0.9550 - val_accuracy: 0.7618
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6521 - accuracy: 0.9186
# Epoch 17: val_loss improved from 0.95502 to 0.93753, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.6521 - accuracy: 0.9186 - val_loss: 0.9375 - val_accuracy: 0.7566
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6150 - accuracy: 0.9201
# Epoch 18: val_loss improved from 0.93753 to 0.89343, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.6150 - accuracy: 0.9201 - val_loss: 0.8934 - val_accuracy: 0.7548
# Epoch 19/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.9182
# Epoch 19: val_loss improved from 0.89343 to 0.78973, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.5891 - accuracy: 0.9182 - val_loss: 0.7897 - val_accuracy: 0.8091
# Epoch 20/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5572 - accuracy: 0.9199
# Epoch 20: val_loss improved from 0.78973 to 0.72967, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.5572 - accuracy: 0.9199 - val_loss: 0.7297 - val_accuracy: 0.8214
# Epoch 21/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.9144
# Epoch 21: val_loss improved from 0.72967 to 0.71908, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.5366 - accuracy: 0.9144 - val_loss: 0.7191 - val_accuracy: 0.8161
# Epoch 22/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5231 - accuracy: 0.9232
# Epoch 22: val_loss improved from 0.71908 to 0.67798, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.5231 - accuracy: 0.9232 - val_loss: 0.6780 - val_accuracy: 0.8433
# Epoch 23/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.9204
# Epoch 23: val_loss improved from 0.67798 to 0.66106, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.5000 - accuracy: 0.9204 - val_loss: 0.6611 - val_accuracy: 0.8424
# Epoch 24/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4974 - accuracy: 0.9175
# Epoch 24: val_loss did not improve from 0.66106
# 36/36 [==============================] - 72s 2s/step - loss: 0.4974 - accuracy: 0.9175 - val_loss: 0.6772 - val_accuracy: 0.8275
# Epoch 25/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.9232
# Epoch 25: val_loss improved from 0.66106 to 0.61329, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4793 - accuracy: 0.9232 - val_loss: 0.6133 - val_accuracy: 0.8581
# Epoch 26/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.9258
# Epoch 26: val_loss improved from 0.61329 to 0.60589, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.4739 - accuracy: 0.9258 - val_loss: 0.6059 - val_accuracy: 0.8660
# Epoch 27/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.9223
# Epoch 27: val_loss did not improve from 0.60589
# 36/36 [==============================] - 73s 2s/step - loss: 0.4636 - accuracy: 0.9223 - val_loss: 0.6142 - val_accuracy: 0.8503
# Epoch 28/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.9282
# Epoch 28: val_loss improved from 0.60589 to 0.57442, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4584 - accuracy: 0.9282 - val_loss: 0.5744 - val_accuracy: 0.8660
# Epoch 29/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.9252
# Epoch 29: val_loss improved from 0.57442 to 0.57077, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.4508 - accuracy: 0.9252 - val_loss: 0.5708 - val_accuracy: 0.8687
# Epoch 30/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.9223
# Epoch 30: val_loss did not improve from 0.57077
# 36/36 [==============================] - 73s 2s/step - loss: 0.4485 - accuracy: 0.9223 - val_loss: 0.5717 - val_accuracy: 0.8643
# Epoch 31/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.9206
# Epoch 31: val_loss improved from 0.57077 to 0.56513, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4458 - accuracy: 0.9206 - val_loss: 0.5651 - val_accuracy: 0.8643
# Epoch 32/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4463 - accuracy: 0.9210
# Epoch 32: val_loss improved from 0.56513 to 0.52962, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4463 - accuracy: 0.9210 - val_loss: 0.5296 - val_accuracy: 0.8818
# Epoch 33/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4384 - accuracy: 0.9256
# Epoch 33: val_loss did not improve from 0.52962
# 36/36 [==============================] - 73s 2s/step - loss: 0.4384 - accuracy: 0.9256 - val_loss: 0.5496 - val_accuracy: 0.8704
# Epoch 34/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4290 - accuracy: 0.9274
# Epoch 34: val_loss improved from 0.52962 to 0.50825, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4290 - accuracy: 0.9274 - val_loss: 0.5082 - val_accuracy: 0.8914
# Epoch 35/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.9284
# Epoch 35: val_loss did not improve from 0.50825
# 36/36 [==============================] - 73s 2s/step - loss: 0.4196 - accuracy: 0.9284 - val_loss: 0.5108 - val_accuracy: 0.8835
# Epoch 36/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4193 - accuracy: 0.9291
# Epoch 36: val_loss did not improve from 0.50825
# 36/36 [==============================] - 73s 2s/step - loss: 0.4193 - accuracy: 0.9291 - val_loss: 0.5107 - val_accuracy: 0.8783
# Epoch 37/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.9311
# Epoch 37: val_loss improved from 0.50825 to 0.46695, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4121 - accuracy: 0.9311 - val_loss: 0.4669 - val_accuracy: 0.9098
# Epoch 38/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.9256
# Epoch 38: val_loss did not improve from 0.46695
# 36/36 [==============================] - 72s 2s/step - loss: 0.4255 - accuracy: 0.9256 - val_loss: 0.4737 - val_accuracy: 0.8967
# Epoch 39/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.9230
# Epoch 39: val_loss did not improve from 0.46695
# 36/36 [==============================] - 72s 2s/step - loss: 0.4123 - accuracy: 0.9230 - val_loss: 0.5001 - val_accuracy: 0.8844
# Epoch 40/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4140 - accuracy: 0.9256
# Epoch 40: val_loss did not improve from 0.46695
# 36/36 [==============================] - 73s 2s/step - loss: 0.4140 - accuracy: 0.9256 - val_loss: 0.4854 - val_accuracy: 0.9081
# Epoch 41/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.9280
# Epoch 41: val_loss improved from 0.46695 to 0.44641, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 74s 2s/step - loss: 0.4123 - accuracy: 0.9280 - val_loss: 0.4464 - val_accuracy: 0.9037
# Epoch 42/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4035 - accuracy: 0.9295
# Epoch 42: val_loss did not improve from 0.44641
# 36/36 [==============================] - 73s 2s/step - loss: 0.4035 - accuracy: 0.9295 - val_loss: 0.4619 - val_accuracy: 0.9072
# Epoch 43/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.9300
# Epoch 43: val_loss did not improve from 0.44641
# 36/36 [==============================] - 73s 2s/step - loss: 0.4002 - accuracy: 0.9300 - val_loss: 0.4578 - val_accuracy: 0.9002
# Epoch 44/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.9263
# Epoch 44: val_loss did not improve from 0.44641
# 36/36 [==============================] - 72s 2s/step - loss: 0.4047 - accuracy: 0.9263 - val_loss: 0.4562 - val_accuracy: 0.9037
# Epoch 45/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3982 - accuracy: 0.9282
# Epoch 45: val_loss improved from 0.44641 to 0.43968, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3982 - accuracy: 0.9282 - val_loss: 0.4397 - val_accuracy: 0.9063
# Epoch 46/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4005 - accuracy: 0.9241
# Epoch 46: val_loss improved from 0.43968 to 0.43511, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.4005 - accuracy: 0.9241 - val_loss: 0.4351 - val_accuracy: 0.9107
# Epoch 47/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.9298
# Epoch 47: val_loss did not improve from 0.43511
# 36/36 [==============================] - 72s 2s/step - loss: 0.4028 - accuracy: 0.9298 - val_loss: 0.4541 - val_accuracy: 0.9037
# Epoch 48/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.9348
# Epoch 48: val_loss did not improve from 0.43511
# 36/36 [==============================] - 72s 2s/step - loss: 0.3927 - accuracy: 0.9348 - val_loss: 0.4565 - val_accuracy: 0.9063
# Epoch 49/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3948 - accuracy: 0.9254
# Epoch 49: val_loss did not improve from 0.43511
# 36/36 [==============================] - 73s 2s/step - loss: 0.3948 - accuracy: 0.9254 - val_loss: 0.4413 - val_accuracy: 0.9116
# Epoch 50/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.9293
# Epoch 50: val_loss improved from 0.43511 to 0.40488, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3916 - accuracy: 0.9293 - val_loss: 0.4049 - val_accuracy: 0.9256
# Epoch 51/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.9370
# Epoch 51: val_loss did not improve from 0.40488
# 36/36 [==============================] - 72s 2s/step - loss: 0.3781 - accuracy: 0.9370 - val_loss: 0.4301 - val_accuracy: 0.9046
# Epoch 52/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3822 - accuracy: 0.9315
# Epoch 52: val_loss did not improve from 0.40488
# 36/36 [==============================] - 73s 2s/step - loss: 0.3822 - accuracy: 0.9315 - val_loss: 0.4268 - val_accuracy: 0.9142
# Epoch 53/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.9344
# Epoch 53: val_loss did not improve from 0.40488
# 36/36 [==============================] - 72s 2s/step - loss: 0.3781 - accuracy: 0.9344 - val_loss: 0.4181 - val_accuracy: 0.9124
# Epoch 54/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3830 - accuracy: 0.9333
# Epoch 54: val_loss did not improve from 0.40488
# 36/36 [==============================] - 73s 2s/step - loss: 0.3830 - accuracy: 0.9333 - val_loss: 0.4215 - val_accuracy: 0.9221
# Epoch 55/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.9330
# Epoch 55: val_loss did not improve from 0.40488
# 36/36 [==============================] - 73s 2s/step - loss: 0.3781 - accuracy: 0.9330 - val_loss: 0.4215 - val_accuracy: 0.9116
# Epoch 56/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.9306
# Epoch 56: val_loss did not improve from 0.40488
# 36/36 [==============================] - 73s 2s/step - loss: 0.3808 - accuracy: 0.9306 - val_loss: 0.4322 - val_accuracy: 0.9063
# Epoch 57/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.9339
# Epoch 57: val_loss did not improve from 0.40488
# 36/36 [==============================] - 73s 2s/step - loss: 0.3798 - accuracy: 0.9339 - val_loss: 0.4106 - val_accuracy: 0.9177
# Epoch 58/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.9322
# Epoch 58: val_loss improved from 0.40488 to 0.39547, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3700 - accuracy: 0.9322 - val_loss: 0.3955 - val_accuracy: 0.9212
# Epoch 59/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.9379
# Epoch 59: val_loss did not improve from 0.39547
# 36/36 [==============================] - 73s 2s/step - loss: 0.3650 - accuracy: 0.9379 - val_loss: 0.4031 - val_accuracy: 0.9264
# Epoch 60/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.9300
# Epoch 60: val_loss did not improve from 0.39547
# 36/36 [==============================] - 73s 2s/step - loss: 0.3731 - accuracy: 0.9300 - val_loss: 0.4103 - val_accuracy: 0.9212
# Epoch 61/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.9333
# Epoch 61: val_loss did not improve from 0.39547
# 36/36 [==============================] - 73s 2s/step - loss: 0.3768 - accuracy: 0.9333 - val_loss: 0.4194 - val_accuracy: 0.9229
# Epoch 62/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.9374
# Epoch 62: val_loss did not improve from 0.39547
# 36/36 [==============================] - 72s 2s/step - loss: 0.3737 - accuracy: 0.9374 - val_loss: 0.4009 - val_accuracy: 0.9212
# Epoch 63/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.9341
# Epoch 63: val_loss did not improve from 0.39547
# 36/36 [==============================] - 72s 2s/step - loss: 0.3710 - accuracy: 0.9341 - val_loss: 0.4022 - val_accuracy: 0.9177
# Epoch 64/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.9394
# Epoch 64: val_loss improved from 0.39547 to 0.39173, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3615 - accuracy: 0.9394 - val_loss: 0.3917 - val_accuracy: 0.9370
# Epoch 65/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.9374
# Epoch 65: val_loss did not improve from 0.39173
# 36/36 [==============================] - 73s 2s/step - loss: 0.3651 - accuracy: 0.9374 - val_loss: 0.3989 - val_accuracy: 0.9194
# Epoch 66/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.9368
# Epoch 66: val_loss did not improve from 0.39173
# 36/36 [==============================] - 72s 2s/step - loss: 0.3631 - accuracy: 0.9368 - val_loss: 0.4140 - val_accuracy: 0.9133
# Epoch 67/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.9372
# Epoch 67: val_loss improved from 0.39173 to 0.39047, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3624 - accuracy: 0.9372 - val_loss: 0.3905 - val_accuracy: 0.9221
# Epoch 68/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.9354
# Epoch 68: val_loss improved from 0.39047 to 0.36905, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3609 - accuracy: 0.9354 - val_loss: 0.3690 - val_accuracy: 0.9396
# Epoch 69/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3639 - accuracy: 0.9365
# Epoch 69: val_loss did not improve from 0.36905
# 36/36 [==============================] - 72s 2s/step - loss: 0.3639 - accuracy: 0.9365 - val_loss: 0.3760 - val_accuracy: 0.9212
# Epoch 70/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.9361
# Epoch 70: val_loss did not improve from 0.36905
# 36/36 [==============================] - 72s 2s/step - loss: 0.3570 - accuracy: 0.9361 - val_loss: 0.3791 - val_accuracy: 0.9212
# Epoch 71/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.9357
# Epoch 71: val_loss did not improve from 0.36905
# 36/36 [==============================] - 73s 2s/step - loss: 0.3547 - accuracy: 0.9357 - val_loss: 0.3720 - val_accuracy: 0.9282
# Epoch 72/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.9330
# Epoch 72: val_loss did not improve from 0.36905
# 36/36 [==============================] - 73s 2s/step - loss: 0.3612 - accuracy: 0.9330 - val_loss: 0.3854 - val_accuracy: 0.9273
# Epoch 73/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.9387
# Epoch 73: val_loss did not improve from 0.36905
# 36/36 [==============================] - 73s 2s/step - loss: 0.3575 - accuracy: 0.9387 - val_loss: 0.3841 - val_accuracy: 0.9247
# Epoch 74/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.9376
# Epoch 74: val_loss did not improve from 0.36905
# 36/36 [==============================] - 73s 2s/step - loss: 0.3451 - accuracy: 0.9376 - val_loss: 0.3777 - val_accuracy: 0.9238
# Epoch 75/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.9346
# Epoch 75: val_loss improved from 0.36905 to 0.35665, saving model to /content/drive/MyDrive/2024urop/model/plain/plain3-bestmodel.keras
# 36/36 [==============================] - 73s 2s/step - loss: 0.3586 - accuracy: 0.9346 - val_loss: 0.3567 - val_accuracy: 0.9396
# Epoch 76/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3565 - accuracy: 0.9348
# Epoch 76: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3565 - accuracy: 0.9348 - val_loss: 0.3679 - val_accuracy: 0.9352
# Epoch 77/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.9374
# Epoch 77: val_loss did not improve from 0.35665
# 36/36 [==============================] - 72s 2s/step - loss: 0.3506 - accuracy: 0.9374 - val_loss: 0.3997 - val_accuracy: 0.9168
# Epoch 78/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.9407
# Epoch 78: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3478 - accuracy: 0.9407 - val_loss: 0.3841 - val_accuracy: 0.9221
# Epoch 79/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.9422
# Epoch 79: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3446 - accuracy: 0.9422 - val_loss: 0.3828 - val_accuracy: 0.9326
# Epoch 80/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.9372
# Epoch 80: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3540 - accuracy: 0.9372 - val_loss: 0.3835 - val_accuracy: 0.9273
# Epoch 81/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.9341
# Epoch 81: val_loss did not improve from 0.35665
# 36/36 [==============================] - 72s 2s/step - loss: 0.3528 - accuracy: 0.9341 - val_loss: 0.3653 - val_accuracy: 0.9326
# Epoch 82/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.9414
# Epoch 82: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3518 - accuracy: 0.9414 - val_loss: 0.3754 - val_accuracy: 0.9282
# Epoch 83/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.9431
# Epoch 83: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3446 - accuracy: 0.9431 - val_loss: 0.3795 - val_accuracy: 0.9264
# Epoch 84/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.9394
# Epoch 84: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3498 - accuracy: 0.9394 - val_loss: 0.3765 - val_accuracy: 0.9326
# Epoch 85/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.9317
# Epoch 85: val_loss did not improve from 0.35665
# 36/36 [==============================] - 73s 2s/step - loss: 0.3554 - accuracy: 0.9317 - val_loss: 0.3668 - val_accuracy: 0.9282

# %%
print("\n Test Accuracy: %4.f" %(model. evaluate(test_ds) [1]))
# Out:
# 11/11 [==============================] - 10s 878ms/step - loss: 0.3671 - accuracy: 0.9329
#
#  Test Accuracy:    1

# %% [markdown]
# # 그래프 표현

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# %%
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']

# %%
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker = '.', c = 'red', label = 'validationset_loss')
plt.plot(x_len, y_loss, marker = '.', c = 'blue', label = 'trainset_loss')
plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vacc, marker = '.', c = 'red', label = 'validationset_accuracy')
plt.plot(x_len, y_acc, marker = '.', c = 'blue', label = 'trainset_accuracy')
plt.legend(loc = 'lower right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# # 혼동 행렬 표현

# %%
train_score = model.evaluate(train_ds ,  verbose = 1)
valid_score = model.evaluate(val_ds ,  verbose = 1)
test_score = model.evaluate(test_ds ,  verbose = 1)
# Out:
# 36/36 [==============================] - 57s 2s/step - loss: 0.3032 - accuracy: 0.9562
# 9/9 [==============================] - 15s 2s/step - loss: 0.3624 - accuracy: 0.9352
# 11/11 [==============================] - 10s 864ms/step - loss: 0.3671 - accuracy: 0.9329

# %%
from sklearn.metrics import confusion_matrix, classification_report
import itertools

# %%
# 모델 예측값 생성
y_pred = np.argmax(model.predict(test_ds), axis=-1)

# 실제 레이블 가져오기 (y_test가 원핫 인코딩된 경우)
y_true = np.argmax(y_test, axis=-1)

# 혼동 행렬 계산 및 출력
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# 11/11 [==============================] - 10s 920ms/step
# [[399   0   5   1]
#  [  0 294   2   4]
#  [  1   1 268  30]
#  [ 14  24   6 262]]

# %%
plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels, rotation= 45)
plt.yticks(tick_marks, labels)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
print("Classification Report:")
report = classification_report(y_true, y_pred, target_names=labels)
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      notumor       0.96      0.99      0.97       405
#    pituitary       0.92      0.98      0.95       300
#       glioma       0.95      0.89      0.92       300
#   meningioma       0.88      0.86      0.87       306
#
#     accuracy                           0.93      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.93      0.93      0.93      1311
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      notumor       0.96      0.99      0.97       405
#    pituitary       0.92      0.98      0.95       300
#       glioma       0.95      0.89      0.92       300
#   meningioma       0.88      0.86      0.87       306
#
#     accuracy                           0.93      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.93      0.93      0.93      1311
